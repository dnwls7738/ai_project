# %%
from ultralytics import YOLO
# Out:
# WARNING Known issue with torch==2.4.0 on Windows with CPU, recommend upgrading to torch>=2.4.1 to resolve https://github.com/ultralytics/ultralytics/issues/15049

# %%
model = YOLO(r"C:/ai_project01/best.pt")

# %%
model.predict(
    source=r"C:\ai_project01\mask_yolo_dataset\images\val", 
    save=True, 
    project=r"C:\ai_project01\runs\detect",
    name="predict",
    exist_ok=True,
)
# Out:
# image 1/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00003.png: 640x640 1 mask_on, 10.3ms
# image 2/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00010.png: 640x640 3 mask_ons, 10.6ms
# image 3/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00023.png: 640x640 1 mask_on, 10.5ms
# image 4/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00025.png: 640x640 1 mask_on, 10.3ms
# image 5/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00030.png: 640x640 2 mask_ons, 10.4ms
# image 6/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00031.png: 640x640 1 mask_on, 9.4ms
# image 7/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00039.png: 640x640 1 mask_on, 10.9ms
# image 8/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00044.png: 640x640 1 mask_on, 10.4ms
# image 9/205 C:\ai_project01\mask_yolo_dataset\images\val\mask_on_00054.png: 640x640 1 mask_on, 10.5ms
# ...
